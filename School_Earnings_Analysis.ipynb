# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# %cd /content/drive/MyDrive/Colab Notebooks
df= pd.read_csv('higher_ed_employee_salaries.csv')
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
df
# Out:
#                         Name                          School  \
# 0                 Don Potter             University of Akron
# 1               Emily Potter       The Ohio State University
# 2          Carol Jean Potter       The Ohio State University
# 3                 Kim Potter       The Ohio State University
# 4              Graham Potter                Miami University
# ...                      ...                             ...
# 934343         Danielle Noon            University of Toledo
# 934344         Danielle Noon            University of Toledo
# 934345  Kristen Lindsay Noon       The Ohio State University
# 934346         Danielle Noon            University of Toledo
# 934347          Kevin R Noon  Bowling Green State University
#
#                        Job Description  \
# 0                   Assistant Lecturer
# 1           Administrative Assistant 3
# 2         Associate Professor-Clinical
# 3                Manager 4, Compliance
# 4       Building and Grounds Assistant
# ...                                ...
# 934343               Medical Assistant
# 934344       Patient Registration Spec
# 934345    Assistant Professor-Clinical
# 934346               Medical Assistant
# 934347      Asst Men's Basketbal Coach
#
#                                                Department   Earnings  Year
# 0                                             Social Work    2472.00  2019
# 1       Arts and Sciences | Chemistry and Biochemistry...   48538.02  2022
# 2                                              Pediatrics   22722.80  2013
# 3                              Legal Affairs | Compliance  170143.44  2022
# 4                     Assoc VP Housing,Dining,Rec,Bus Svc    3075.20  2012
# ...                                                   ...        ...   ...
# 934343                               OP-Clinic-Orthopedic   31659.43  2021
# 934344                                       Registration    7974.25  2019
# 934345                                     Anesthesiology  243033.56  2018
# 934346                               OP-Clinic-Orthopedic   37642.16  2022
# 934347                                   Basketball - Men  103630.58  2022
#
# [848591 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934348 entries, 0 to 934347
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Name             934348 non-null  object
#  1   School           934348 non-null  object
#  2   Job Description  907680 non-null  object
#  3   Department       873896 non-null  object
#  4   Earnings         924673 non-null  float64
#  5   Year             934348 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 42.8+ MB

# %%
df.describe()

# %%
df.dropna(inplace=True)

# %%
#Highest Student Counts in Schools
student_count = df.groupby('School')[['Name']].nunique()
student_count.sort_values('Name',ascending = False)
# Out:
#                                   Name
# School
# The Ohio State University       127731
# University of Toledo             20252
# Kent State University            17149
# Miami University                 15280
# University Of Cincinnati         15238
# Ohio University                  13883
# Wright State University          12135
# Bowling Green State University    8337
# Youngstown State University       6833
# University of Akron               6490
# Cleveland State University        5481
# Central State University          1716
# Shawnee State University          1686

# %%
#Avg Salaries Secured from Schools
avg_earn_scl = df.groupby('School')['Earnings'].mean()
avg_earn_scl.sort_values(ascending=False)
# Out:
# School
# The Ohio State University         61318.960181
# University Of Cincinnati          56195.946459
# Cleveland State University        56151.806804
# Ohio University                   55218.448567
# Bowling Green State University    52098.559181
# University of Toledo              51089.495305
# Wright State University           50802.415859
# Miami University                  47126.453988
# Kent State University             44468.285752
# University of Akron               41253.642497
# Central State University          39036.842019
# Shawnee State University          30332.294781
# Youngstown State University       27265.279131
# Name: Earnings, dtype: float64

# %%
#Top Paying Departments
top_earn_dept= df.groupby('Department')['Earnings'].max()
top_earn_dept.sort_values(ascending=False).head(10)
# Out:
# Department
# Athletics | Football                            8021376.56
# Athletics Football                              5986348.94
# Athletics                                       5951221.47
# Athletics | Basketball Men                      3108721.18
# Athletics | Administration                      2672800.02
# Advancement Services                            2537527.11
# Health Sciences Admin RU                        2307367.12
# Internal Medicine                               1981634.52
# Office of the CFO                               1885596.42
# Business and Finance | Office of Investments    1826263.14
# Name: Earnings, dtype: float64

# %%
#Example of using multiple fields in Groupby method
op_earn_scl_dept = df.groupby(['School','Department'])['Earnings'].max()
top_earn_scl_dept.sort_values(ascending=False).reset_index().head(10)
# Out:
#                       School                                    Department  \
# 0  The Ohio State University                          Athletics | Football
# 1   University Of Cincinnati                            Athletics Football
# 2  The Ohio State University                                     Athletics
# 3  The Ohio State University                    Athletics | Basketball Men
# 4  The Ohio State University                    Athletics | Administration
# 5  The Ohio State University                          Advancement Services
# 6  The Ohio State University                      Health Sciences Admin RU
# 7  The Ohio State University                             Internal Medicine
# 8  The Ohio State University                             Office of the CFO
# 9  The Ohio State University  Business and Finance | Office of Investments
#
#      Earnings
# 0  8021376.56
# 1  5986348.94
# 2  5951221.47
# 3  3108721.18
# 4  2672800.02
# 5  2537527.11
# 6  2307367.12
# 7  1981634.52
# 8  1885596.42
# 9  1826263.14

# %%
#Top Schools with Pedatricians
peds = df[df['Department']=='Pediatrics']
peds['School'].value_counts()
# Out:
# School
# The Ohio State University    4426
# University of Toledo          332
# Wright State University       243
# Ohio University                 5
# Name: count, dtype: int64

# %%
#Using lambda function to attach '$' in front of 'Earnings' content.
df['Earnings'] = df['Earnings'].apply(lambda x: f'${x}' )
df.head(20)
# Out:
#                     Name                          School  \
# 0             Don Potter             University of Akron
# 1           Emily Potter       The Ohio State University
# 2      Carol Jean Potter       The Ohio State University
# 3             Kim Potter       The Ohio State University
# 4          Graham Potter                Miami University
# 5          Amanda Potter       The Ohio State University
# 6     Susan Marie Potter       The Ohio State University
# 7         Katrina Potter                Miami University
# 8     Pamela Lynn Potter  Bowling Green State University
# 9      Kimberly J Potter       The Ohio State University
# 10           Adam Potter       The Ohio State University
# 11          Maria Potter        Central State University
# 12          Scott Potter       The Ohio State University
# 13         Ryan M Potter       The Ohio State University
# 14         Archie Potter                 Ohio University
# 15       Jesse W. Potter     Youngstown State University
# 16            Kim Potter       The Ohio State University
# 17     Carol Jean Potter       The Ohio State University
# 18       Kimberly Potter       The Ohio State University
# 19  Richard Scott Potter       The Ohio State University
#
#                    Job Description  \
# 0               Assistant Lecturer
# 1       Administrative Assistant 3
# 2     Associate Professor-Clinical
# 3            Manager 4, Compliance
# 4   Building and Grounds Assistant
# 5              Program Coordinator
# 6                  Program Manager
# 7             Personnel Technician
# 8       Administrative Assistant 2
# 9   Policy Anlyst/Compliance Offcr
# 10  Assistant Professor - Clinical
# 11             Program Coordinator
# 12                     Director-00
# 13                 Assistant Coach
# 14                     Facilitator
# 15              Assistant Director
# 16                     Director-00
# 17    Associate Professor-Clinical
# 18                     Director-00
# 19             Research Specialist
#
#                                            Department    Earnings  Year
# 0                                         Social Work     $2472.0  2019
# 1   Arts and Sciences | Chemistry and Biochemistry...   $48538.02  2022
# 2                                          Pediatrics    $22722.8  2013
# 3                          Legal Affairs | Compliance  $170143.44  2022
# 4                 Assoc VP Housing,Dining,Rec,Bus Svc     $3075.2  2012
# 5                                       WCA-Education   $48806.72  2013
# 6                                  College of Nursing    $65216.0  2013
# 7                           VP for Acad Affrs-Provost   $24324.14  2012
# 8                      Center for Teaching & Learning   $51496.58  2012
# 9                        Legal Affairs Administration    $20868.0  2015
# 10              Medicine | IM Cardiovascular Medicine  $182512.15  2022
# 11                 SAFRA: 2018-2019 Ctr for Global Ed   $39999.96  2018
# 12                                         University  $254467.84  2021
# 13                                          Athletics    $48863.8  2013
# 14                               LLL Undergrad Online     $2450.0  2014
# 15                            Athletic Administration    $45547.2  2015
# 16                                         University  $125232.25  2021
# 17                                         Pediatrics   $28444.65  2015
# 18                       Legal Affairs Administration   $109248.0  2020
# 19                     Office of Energy & Environment   $130120.0  2013

# %%
#Removing '$' sign from 'Earning' column's content to perform aggragation based on the same column.
df['Earnings'] = df['Earnings'].str.replace('$','').astype(float)
top_earn_jd = df.groupby('Job Description')['Earnings'].max()
top_earn_jd.dropna(inplace=True)
top_earn_jd.head(20).sort_values(ascending=False)
# Out:
# Job Description
# 'Director of Energy Programs and Director of Human Capital    141658.10
# 0                                                              68750.00
# 2nd Asst Mens Baskball Coach                                   63357.50
# 2nd Asst Volleyball Coach                                      56918.06
# 1890 Post&Pre Award Admin                                      52908.76
# 1 Smstr Temp                                                   51704.71
# 1890 Research Administrator                                    51187.50
# 21st Century Community L                                       46255.00
# 1st Asst Softball Coach                                        44046.08
# 3 D Technician Sculpture                                       42200.00
# 3 D Technician                                                 24288.00
# 1 Smstr Temp - Univ College                                    22837.00
# 1 Smstr Temp, Sr Instr, Eng/Hum                                20300.00
# 1 Smstr Temp - Eng/Hum                                         19037.50
# 12 Mo PT Secretary 1                                           18973.23
# 1 Smstr Temp -Eng/Hum                                          18562.50
# 1 Smstr Temp, Eng/Hum                                          14225.00
# 2021-22: 54                                                     8508.24
# .07                                                             3899.98
# 2022-23:66                                                       500.00
# Name: Earnings, dtype: float64

# %%
#Getting a variety of aggragtion with custom column names using .agg() method with groupby
max_n_mean = df.groupby('School').agg(max_earn = ('Earnings','max'),mean_earn=('Earnings','mean'),headcount=("Name",'nunique'))
max_n_mean.head(20).sort_values(by='headcount',ascending=False)
# Out:
#                                   max_earn     mean_earn  headcount
# School
# The Ohio State University       8021376.56  61318.960181     127731
# University of Toledo            1230000.10  51089.495305      20252
# Kent State University            499035.00  44468.285752      17149
# Miami University                 757017.28  47126.453988      15280
# University Of Cincinnati        5986348.94  56195.946459      15238
# Ohio University                  753260.13  55218.448567      13883
# Wright State University          827873.36  50802.415859      12135
# Bowling Green State University   539437.50  52098.559181       8337
# Youngstown State University      523880.48  27265.279131       6833
# University of Akron              701999.96  41253.642497       6490
# Cleveland State University      1398108.45  56151.806804       5481
# Central State University         300000.00  39036.842019       1716
# Shawnee State University         327818.10  30332.294781       1686

# %%
#Plotting of the variation in the headcount over the years for top 5 Schools
import matplotlib.pyplot as plt
pvt= df.pivot_table(index='School',columns='Year',values='Name',aggfunc='nunique',fill_value=0)
pvt['Total'] = pvt.sum(axis=1)
pvt_sorted = pvt.sort_values('Total',ascending=False).head(5)
del pvt_sorted['Total']
pvt_sorted.T.plot(marker='o', grid=True, title='Headcount variation over years in top 5 Schools')
plt.ylabel('Headcount')
plt.legend(loc='center left', bbox_to_anchor=(1,0.85))
plt.show()

# %%
#Merging two dataframes based on a column
top_scl_earn = df.groupby('School').agg(Earning=('Earnings',max))
top_scl_earn.sort_values('Earning', ascending=False).head(10)
top_earner = df[['Name','Earnings','School']].sort_values(by='Earnings', ascending = False).head(5)
top_earner
merged = df.merge(top_earner,on = "Name", how="inner")
merged
# Out:
#                       Name                   School_x  \
# 0   Christopher A Holtmann  The Ohio State University
# 1   Christopher A Holtmann  The Ohio State University
# 2                 Ryan Day  The Ohio State University
# 3                 Ryan Day  The Ohio State University
# 4                 Ryan Day  The Ohio State University
# 5                 Ryan Day  The Ohio State University
# 6                 Ryan Day  The Ohio State University
# 7                 Ryan Day  The Ohio State University
# 8        Thomas Tuberville   University Of Cincinnati
# 9        Thomas Tuberville   University Of Cincinnati
# 10      Thad Michael Matta  The Ohio State University
# 11      Thad Michael Matta  The Ohio State University
# 12      Thad Michael Matta  The Ohio State University
# 13      Thad Michael Matta  The Ohio State University
# 14      Thad Michael Matta  The Ohio State University
# 15      Thad Michael Matta  The Ohio State University
#
#             Job Description            Department  Earnings_x  Year  \
# 0   Head Coach-Major Sports             Athletics  5663248.58  2017
# 1   Head Coach-Major Sports             Athletics  1410624.44  2018
# 2   Head Coach-Major Sports  Athletics | Football  8021376.56  2022
# 3   Head Coach-Major Sports  Athletics | Football  8021376.56  2022
# 4   Head Coach-Major Sports             Athletics  4948639.79  2020
# 5   Head Coach-Major Sports             Athletics  4948639.79  2020
# 6   Head Coach-Major Sports             Athletics  5951221.47  2021
# 7   Head Coach-Major Sports             Athletics  5951221.47  2021
# 8   Head Coach Major Sports    Athletics Football  2341022.69  2015
# 9   Head Coach Major Sports    Athletics Football  5986348.94  2013
# 10  Head Coach-Major Sports             Athletics  2634050.12  2013
# 11  Head Coach-Major Sports             Athletics  1929603.31  2017
# 12  Head Coach-Major Sports             Athletics  5776737.21  2015
# 13  Head Coach-Major Sports             Athletics  2654380.16  2014
# 14  Head Coach-Major Sports             Athletics  3386880.08  2016
# 15  Head Coach-Major Sports             Athletics  1516969.80  2018
#
#     Earnings_y                   School_y
# 0   5663248.58  The Ohio State University
# 1   5663248.58  The Ohio State University
# 2   8021376.56  The Ohio State University
# 3   5951221.47  The Ohio State University
# 4   8021376.56  The Ohio State University
# 5   5951221.47  The Ohio State University
# 6   8021376.56  The Ohio State University
# 7   5951221.47  The Ohio State University
# 8   5986348.94   University Of Cincinnati
# 9   5986348.94   University Of Cincinnati
# 10  5776737.21  The Ohio State University
# 11  5776737.21  The Ohio State University
# 12  5776737.21  The Ohio State University
# 13  5776737.21  The Ohio State University
# 14  5776737.21  The Ohio State University
# 15  5776737.21  The Ohio State University

# %%
#Showing yearly increment comparison betweeen two individuals
increment = df.pivot_table(index='Year',columns='Name',values='Earnings', aggfunc='sum')
increment.loc[:,['A Amy French','Kevin R Noon']].plot.bar(ylabel='Salary')
# Out:
# <Axes: xlabel='Year', ylabel='Salary'>

# %%
#Analysisng only for Pediatrics Department
testdf = df[df.loc[:,'Department'].isin(['Pediatrics'])]
testdf = testdf[['Name','School','Department','Earnings']].set_index('Name')
testdf
# Out:
#                                        School  Department  Earnings
# Name
# Carol Jean Potter   The Ohio State University  Pediatrics  22722.80
# Carol Jean Potter   The Ohio State University  Pediatrics  28444.65
# Carol Jean Potter   The Ohio State University  Pediatrics  49421.56
# Carol Potter        The Ohio State University  Pediatrics  51060.36
# Carol Jean Potter   The Ohio State University  Pediatrics  48353.20
# ...                                       ...         ...       ...
# Arielle Sheftall    The Ohio State University  Pediatrics  26079.60
# Karen J Tenenblatt  The Ohio State University  Pediatrics  11540.34
# Karen J Tenenblatt  The Ohio State University  Pediatrics  17245.67
# Karen J Tenenblatt  The Ohio State University  Pediatrics  21378.77
# Karen J Tenenblatt  The Ohio State University  Pediatrics  11283.91
#
# [5006 rows x 3 columns]

# %%
#Removing The Ohio State University's data to get a picture for other schools using .qeury()
testdf.query("School != 'The Ohio State University'")
# Out:
#                                           School  Department   Earnings
# Name
# Diane Ludwig                University of Toledo  Pediatrics   17490.19
# J Joe Hoo                   University of Toledo  Pediatrics   60535.81
# Jermica L. Hood          Wright State University  Pediatrics    4706.00
# Julie Harris                University of Toledo  Pediatrics   62289.65
# Eileen Quinn                University of Toledo  Pediatrics   65494.02
# ...                                          ...         ...        ...
# John M. Pascoe           Wright State University  Pediatrics  207757.68
# John M. Pascoe           Wright State University  Pediatrics  207757.68
# John M. Pascoe           Wright State University  Pediatrics  205957.80
# John Pascoe              Wright State University  Pediatrics  196436.76
# M. Jamy Walters-Collins     University of Toledo  Pediatrics   26242.71
#
# [580 rows x 3 columns]

# %%
#Flagging individuals' salary as low and high using .where() and filtering high earning individuals
testdf = testdf.query("School != 'The Ohio State University'")
testdf['Earning_Level'] = testdf['Earnings'].where(testdf['Earnings']>testdf['Earnings'].mean(),'low')
testdf['Earning_Level'] = testdf['Earning_Level'].where(testdf['Earning_Level']=='low','high')
testdf.head(15)
# Out:
#                                           School  Department  Earnings  \
# Name
# Diane Ludwig                University of Toledo  Pediatrics  17490.19
# J Joe Hoo                   University of Toledo  Pediatrics  60535.81
# Jermica L. Hood          Wright State University  Pediatrics   4706.00
# Julie Harris                University of Toledo  Pediatrics  62289.65
# Eileen Quinn                University of Toledo  Pediatrics  65494.02
# Merrilee Cox             Wright State University  Pediatrics  92434.80
# Tiffany Akeman              University of Toledo  Pediatrics   2689.40
# Tiffany Akeman              University of Toledo  Pediatrics  16000.43
# Kathleen Lavrar             University of Toledo  Pediatrics  37940.59
# Kathleen Lavrar             University of Toledo  Pediatrics  39692.19
# Kathleen Lavrar             University of Toledo  Pediatrics   8157.44
# Kathleen Lavrar             University of Toledo  Pediatrics  37502.76
# Susan S. Howard          Wright State University  Pediatrics  40157.31
# Dionne Michelle Simmons  Wright State University  Pediatrics  64269.12
# Paula Esken              Wright State University  Pediatrics  30127.68
#
#                         Earning_Level
# Name
# Diane Ludwig                      low
# J Joe Hoo                         low
# Jermica L. Hood                   low
# Julie Harris                      low
# Eileen Quinn                      low
# Merrilee Cox                     high
# Tiffany Akeman                    low
# Tiffany Akeman                    low
# Kathleen Lavrar                   low
# Kathleen Lavrar                   low
# Kathleen Lavrar                   low
# Kathleen Lavrar                   low
# Susan S. Howard                   low
# Dionne Michelle Simmons           low
# Paula Esken                       low
